# %% [markdown]
# https://www.mongodb.com/developer/products/atlas/rag-with-polm-stack-llamaindex-openai-mongodb/

# %% [markdown]
# https://www.mongodb.com/developer/products/atlas/rag-atlas-vector-search-langchain-openai/

# %%
'''!pip install llama-index

# !pip install llama-index-vector-stores-mongodb

# !pip install llama-index-embeddings-openai

# !pip install pymongo

# !pip install datasets

# !pip install pandas'''
# Out:
# '!pip install llama-index\n\n!pip install llama-index-vector-stores-mongodb\n\n!pip install llama-index-embeddings-openai\n\n!pip install pymongo\n\n!pip install datasets\n\n!pip install pandas'

# %%
'''from datasets import load_dataset

import pandas as pd

# https://huggingface.co/datasets/AIatMongoDB/embedded\_movies

dataset=load_dataset("")
# pdf is the dataset 

# Convert the dataset to a pandas dataframe

dataset_df=pd.DataFrame(dataset['train'])

dataset_df.head(5)'''
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# <>:1: SyntaxWarning: invalid escape sequence '\_'
# /var/folders/50/brhyf5qd1gd028v14zg49cxw0000gn/T/ipykernel_39075/1278460674.py:1: SyntaxWarning: invalid escape sequence '\_'
#   '''from datasets import load_dataset
# 'from datasets import load_dataset\n\nimport pandas as pd\n\n# https://huggingface.co/datasets/AIatMongoDB/embedded\\_movies\n\ndataset=load_dataset("")\n# pdf is the dataset \n\n# Convert the dataset to a pandas dataframe\n\ndataset_df=pd.DataFrame(dataset[\'train\'])\n\ndataset_df.head(5)'

# %%
# !pip install langchain 
# !pip install pymongo==4.4.1
# !pip install bs4 
# !pip install openai 
# !pip install tiktoken 
# !pip install gradio 
# !pip install requests 
# !pip install lxml 
# !pip install argparse 
# !pip install unstructured
# Out:
# Requirement already satisfied: langchain in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (0.1.16)
# Requirement already satisfied: PyYAML>=5.3 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from langchain) (2.0.29)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from langchain) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from langchain) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.32 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from langchain) (0.0.34)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.42 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from langchain) (0.1.45)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from langchain) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from langchain) (0.1.50)
# Requirement already satisfied: numpy<2,>=1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from langchain) (2.7.1)
# Requirement already satisfied: requests<3,>=2 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: packaging<24.0,>=23.2 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from langchain-core<0.2.0,>=0.1.42->langchain) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: pymongo==4.4.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (4.4.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from pymongo==4.4.1) (2.6.1)
# Requirement already satisfied: bs4 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from beautifulsoup4->bs4) (2.5)
# Requirement already satisfied: openai in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (1.23.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from openai) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from openai) (2.7.1)
# Requirement already satisfied: sniffio in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.18.2)
# Requirement already satisfied: tiktoken in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (0.6.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from tiktoken) (2024.4.16)
# Requirement already satisfied: requests>=2.26.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (2024.2.2)
# Requirement already satisfied: gradio in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (4.27.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (5.3.0)
# Requirement already satisfied: fastapi in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (0.110.2)
# Requirement already satisfied: ffmpy in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (0.3.2)
# Requirement already satisfied: gradio-client==0.15.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (0.15.1)
# Requirement already satisfied: httpx>=0.24.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (0.22.2)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (3.8.4)
# Requirement already satisfied: numpy~=1.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (3.10.1)
# Requirement already satisfied: packaging in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<11.0,>=8.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (10.3.0)
# Requirement already satisfied: pydantic>=2.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (2.7.1)
# Requirement already satisfied: pydub in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (0.4.1)
# Requirement already satisfied: semantic-version~=2.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (0.12.3)
# Requirement already satisfied: typing-extensions~=4.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (4.11.0)
# Requirement already satisfied: urllib3~=2.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (2.2.1)
# Requirement already satisfied: uvicorn>=0.14.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio) (0.29.0)
# Requirement already satisfied: fsspec in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio-client==0.15.1->gradio) (2024.3.1)
# Requirement already satisfied: websockets<12.0,>=10.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from gradio-client==0.15.1->gradio) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from altair<6.0,>=4.2.0->gradio) (4.21.1)
# Requirement already satisfied: toolz in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.1)
# Requirement already satisfied: anyio in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from httpx>=0.24.1->gradio) (4.3.0)
# Requirement already satisfied: certifi in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from httpx>=0.24.1->gradio) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: idna in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from httpx>=0.24.1->gradio) (3.7)
# Requirement already satisfied: sniffio in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from httpx>=0.24.1->gradio) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.19.3->gradio) (3.13.4)
# Requirement already satisfied: requests in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from matplotlib~=3.0->gradio) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from matplotlib~=3.0->gradio) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from matplotlib~=3.0->gradio) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from matplotlib~=3.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from pydantic>=2.0->gradio) (2.18.2)
# Requirement already satisfied: click>=8.0.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from fastapi->gradio) (0.37.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.18.0)
# Requirement already satisfied: six>=1.5 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.17.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.19.3->gradio) (3.3.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: requests in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from requests) (2024.2.2)
# Requirement already satisfied: lxml in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (5.2.1)
# Collecting argparse
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0
# Requirement already satisfied: unstructured in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (0.11.8)
# Requirement already satisfied: chardet in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured) (5.2.1)
# Requirement already satisfied: nltk in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured) (3.8.1)
# Requirement already satisfied: tabulate in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured) (0.9.0)
# Requirement already satisfied: requests in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured) (4.12.3)
# Requirement already satisfied: emoji in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured) (2.11.1)
# Requirement already satisfied: dataclasses-json in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured) (0.6.4)
# Requirement already satisfied: python-iso639 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured) (2024.2.7)
# Requirement already satisfied: langdetect in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured) (1.26.4)
# Requirement already satisfied: rapidfuzz in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured) (3.8.1)
# Requirement already satisfied: backoff in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured) (4.11.0)
# Requirement already satisfied: unstructured-client in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured) (0.22.0)
# Requirement already satisfied: wrapt in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from beautifulsoup4->unstructured) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from dataclasses-json->unstructured) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from langdetect->unstructured) (1.16.0)
# Requirement already satisfied: click in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from nltk->unstructured) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from nltk->unstructured) (2024.4.16)
# Requirement already satisfied: tqdm in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from nltk->unstructured) (4.66.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from requests->unstructured) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from requests->unstructured) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from requests->unstructured) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from requests->unstructured) (2024.2.2)
# Requirement already satisfied: deepdiff>=6.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (7.0.1)
# Requirement already satisfied: jsonpath-python>=1.0.6 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (1.0.6)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: packaging>=23.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (23.2)
# Requirement already satisfied: pypdf>=4.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (4.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (2.9.0.post0)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from deepdiff>=6.0->unstructured-client->unstructured) (4.1.0)

# %%
# !pip install PyPDF2==3.0.1
# Out:
# Requirement already satisfied: PyPDF2==3.0.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (3.0.1)

# %%
# !pip install pdfplumber==0.11.0
# Out:
# Requirement already satisfied: pdfplumber==0.11.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (0.11.0)
# Requirement already satisfied: pdfminer.six==20231228 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from pdfplumber==0.11.0) (20231228)
# Requirement already satisfied: Pillow>=9.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from pdfplumber==0.11.0) (10.3.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from pdfplumber==0.11.0) (4.29.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from pdfminer.six==20231228->pdfplumber==0.11.0) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from pdfminer.six==20231228->pdfplumber==0.11.0) (42.0.5)
# Requirement already satisfied: cffi>=1.12 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber==0.11.0) (1.16.0)
# Requirement already satisfied: pycparser in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber==0.11.0) (2.22)

# %%
# !pip install pymongo==4.4.1
# Out:
# Requirement already satisfied: pymongo==4.4.1 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (4.4.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages (from pymongo==4.4.1) (2.6.1)

# %%
from pymongo import MongoClient
from pymongo.server_api import ServerApi
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import MongoDBAtlasVectorSearch
from langchain.document_loaders import DirectoryLoader
from langchain.llms import OpenAI
from langchain.chains import RetrievalQA
#import gradio as gr
#from gradio.themes.base import Base
#import key_param
#from gradio import key_param
from PyPDF2 import PdfReader 
from pdfplumber import pdf
from dotenv import load_dotenv
import os

# %%
load_dotenv()
mongopasswd = os.getenv('CM_MONGO_PASS')
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

# %%
MONGO_URI = f'mongodb+srv://cmitchem:{mongopasswd}@cluster0.pshckj2.mongodb.net/?authSourse=admin&tls=true&tlsAllowInvalidCertificates=true&retryWrites=true&w=majority&appName=Cluster0'

client = MongoClient(MONGO_URI, server_api=ServerApi('1'))
 
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
 
print(client.list_database_names())
db = client["city_of_fort_worth_vector_db"]
collection = db["city_of_fort_worth_vector_collection"]
doc = collection.find_one()
print(doc)
# Out:
# /Users/carolinemitchem/Desktop/cofw-plat-ai/.venv/lib/python3.12/site-packages/pymongo/common.py:840: UserWarning: Unknown option authsourse
#   warnings.warn(str(exc))
# Pinged your deployment. You successfully connected to MongoDB!
# ['admin', 'city_of_fort_worth_vector_db', 'config', 'local', 'sample_airbnb', 'sample_analytics', 'sample_geospatial', 'sample_guides', 'sample_mflix', 'sample_restaurants', 'sample_supplies', 'sample_training', 'sample_weatherdata']
# {'_id': ObjectId('661b32360963d098e36558bc'), 'name': 'first field in fw db\n'}

# %%
docs = collection.find()
print(docs)
# Out:
# <pymongo.cursor.Cursor object at 0x3020b5e80>

# %%
'''MONGO_URI = f'mongodb+srv://istrzhemechny:{mongopasswd}@cluster0.fyxvpen.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'


client = MongoClient(MONGO_URI)
dbName = "Rag_Demo"
collectionName = "Embeddings_Collection"
collection = client[dbName][collectionName]'''
# Out:
# 'MONGO_URI = f\'mongodb+srv://istrzhemechny:{mongopasswd}@cluster0.fyxvpen.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0\'\n\n\nclient = MongoClient(MONGO_URI)\ndbName = "Rag_Demo"\ncollectionName = "Embeddings_Collection"\ncollection = client[dbName][collectionName]'

# %%
embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)

# %%
#Load and read the PDF
pdf_loader = PdfReader("The Road Not Taken Poem.pdf")
#pdf_loader = PdfReader("File-2.pdf")
#pdf_loader = PdfReader("File-3.pdf")
# pdf_loader = PdfReader("File-4.pdf") # too long!
#pdf_loader = PdfReader("File-5.pdf")
# pdf_loader = PdfReader("File-6.pdf") # too long
# pdf_loader = PdfReader("File-7.pdf") #empty: need to make OCR file to read
#pdf_loader = PdfReader("File-8.pdf")
#pdf_loader = PdfReader("File-9.pdf") # also long, did not embed
pdf_text = ""
for page_num in range(len(pdf_loader.pages)):
    pdf_page = pdf_loader.pages[page_num]
    pdf_text += pdf_page.extract_text()

print(type(pdf_text))
# Out:
# <class 'str'>

# %%
loader = DirectoryLoader( './sample_files', glob="./*.txt", show_progress=True)
# sample_files == local folder with testing text file 
data = loader.load()

vectorStore = MongoDBAtlasVectorSearch.from_documents(data, embeddings, collection=collection )
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 78.25it/s]

# %%
print(vectorStore)
# Out:
# <langchain_community.vectorstores.mongodb_atlas.MongoDBAtlasVectorSearch object at 0x3021fc9e0>

# %%
embeddings = OpenAIEmbeddings(openai_api_key=key_param.openai_api_key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 embeddings = OpenAIEmbeddings(openai_api_key=key_param.openai_api_key)
#
# NameError: name 'key_param' is not defined

# %%
vectorStore = MongoDBAtlasVectorSearch( collection, embeddings )

def query_data(query):
    # Convert question to vector using OpenAI embeddings
    # Perform Atlas Vector Search using Langchain's vectorStore
    # similarity_search returns MongoDB documents most similar to the query    

    docs = vectorStore.similarity_search(query, K=1)
  as_output = docs[0].page_content

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=49d00240-a8a6-4b0d-8544-487265eb2619' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
